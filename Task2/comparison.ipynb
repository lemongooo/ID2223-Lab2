# %%
# !pip install gradio transformers unsloth
# Out:
# Collecting gradio
#   Downloading gradio-5.8.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.3)
# Collecting unsloth
#   Downloading unsloth-2024.12.4-py3-none-any.whl.metadata (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 3.3 MB/s eta 0:00:00
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.115.6-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.5.1 (from gradio)
#   Downloading gradio_client-1.5.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.28.0)
# Requirement already satisfied: huggingface-hub>=0.25.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.26.3)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.4)
# Collecting markupsafe~=2.0 (from gradio)
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.10.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (11.0.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.10.3)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Downloading python_multipart-0.0.19-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.2)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.8.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio)
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.15.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.12.2)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.32.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.5.1->gradio) (2024.10.0)
# Collecting websockets<15.0,>=10.0 (from gradio-client==1.5.1->gradio)
#   Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Collecting unsloth_zoo>=2024.11.8 (from unsloth)
#   Downloading unsloth_zoo-2024.12.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (2.5.1+cu121)
# Collecting xformers>=0.0.27.post2 (from unsloth)
#   Downloading xformers-0.0.28.post3-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting bitsandbytes (from unsloth)
#   Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# Collecting triton>=3.0.0 (from unsloth)
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting tyro (from unsloth)
#   Downloading tyro-0.9.2-py3-none-any.whl.metadata (9.4 kB)
# Collecting datasets>=2.16.0 (from unsloth)
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.2.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unsloth) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.45.1)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.10/dist-packages (from unsloth) (1.1.1)
# Collecting trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 (from unsloth)
#   Downloading trl-0.12.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.13.2)
# Collecting protobuf<4.0.0 (from unsloth)
#   Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (679 bytes)
# Collecting hf_transfer (from unsloth)
#   Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.2.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.16.0->unsloth)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets>=2.16.0->unsloth)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.16.0->unsloth)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec (from gradio-client==1.5.1->gradio)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (3.11.9)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->unsloth) (3.4.2)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->unsloth) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (13.9.4)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Collecting cut_cross_entropy (from unsloth_zoo>=2024.11.8->unsloth)
#   Downloading cut_cross_entropy-24.12.2-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth) (0.16)
# Collecting shtab>=1.5.6 (from tyro->unsloth)
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth) (4.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (0.1.2)
# Downloading gradio-5.8.0-py3-none-any.whl (57.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 MB 35.6 MB/s eta 0:00:00
# Downloading gradio_client-1.5.1-py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.2/320.2 kB 29.2 MB/s eta 0:00:00
# Downloading unsloth-2024.12.4-py3-none-any.whl (174 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.2/174.2 kB 17.9 MB/s eta 0:00:00
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 39.9 MB/s eta 0:00:00
# Downloading fastapi-0.115.6-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 10.3 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 55.9 MB/s eta 0:00:00
# Downloading python_multipart-0.0.19-py3-none-any.whl (24 kB)
# Downloading ruff-0.8.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 122.7 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 8.4 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 3.7 MB/s eta 0:00:00
# Downloading trl-0.12.2-py3-none-any.whl (365 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 31.4 MB/s eta 0:00:00
# Downloading unsloth_zoo-2024.12.1-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 6.6 MB/s eta 0:00:00
# Downloading uvicorn-0.32.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 6.6 MB/s eta 0:00:00
# Downloading xformers-0.0.28.post3-cp310-cp310-manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 100.4 MB/s eta 0:00:00
# Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 28.9 MB/s eta 0:00:00
# Downloading ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 98.3 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading tyro-0.9.2-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.1/112.1 kB 11.3 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.2 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.2 MB/s eta 0:00:00
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading websockets-14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.2/168.2 kB 15.9 MB/s eta 0:00:00
# Downloading cut_cross_entropy-24.12.2-py3-none-any.whl (22 kB)
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.5 MB/s eta 0:00:00
# Installing collected packages: pydub, xxhash, websockets, uvicorn, triton, tomlkit, shtab, semantic-version, ruff, python-multipart, protobuf, markupsafe, hf_transfer, fsspec, ffmpy, dill, aiofiles, starlette, multiprocess, tyro, safehttpx, gradio-client, fastapi, xformers, gradio, cut_cross_entropy, bitsandbytes, datasets, trl, unsloth_zoo, unsloth
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed aiofiles-23.2.1 bitsandbytes-0.45.0 cut_cross_entropy-24.12.2 datasets-3.2.0 dill-0.3.8 fastapi-0.115.6 ffmpy-0.4.0 fsspec-2024.9.0 gradio-5.8.0 gradio-client-1.5.1 hf_transfer-0.1.8 markupsafe-2.1.5 multiprocess-0.70.16 protobuf-3.20.3 pydub-0.25.1 python-multipart-0.0.19 ruff-0.8.2 safehttpx-0.1.6 semantic-version-2.10.0 shtab-1.7.1 starlette-0.41.3 tomlkit-0.13.2 triton-3.1.0 trl-0.12.2 tyro-0.9.2 unsloth-2024.12.4 unsloth_zoo-2024.12.1 uvicorn-0.32.1 websockets-14.1 xformers-0.0.28.post3 xxhash-3.5.0

# %%
# !pip install rouge-score
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.66.6)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=d4cedddf28f60b17223e0090f797a7431f7dfcc1dfe2ee511e72abc21fa64208
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
from unsloth import FastLanguageModel
import torch
from rouge_score import rouge_scorer
import nltk
import numpy as np

try:
    nltk.download('punkt')
    nltk.download('punkt_tab')
except:
    pass

def load_model(model_name):
    """loading model"""
    print(f"loading {model_name}...")
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name=model_name,
        max_seq_length=2048,
        dtype=torch.float16,
        load_in_4bit=True
    )
    model = FastLanguageModel.for_inference(model)
    print("finish")
    return model, tokenizer

model1_name = "lemongooooo/lora_data_0"
model1, tokenizer1 = load_model(model1_name)

model2_name = "lemongooooo/lora_data_200k"
model2, tokenizer2 = load_model(model2_name)

model3_name = "lemongooooo/lora_data_300k"
model3, tokenizer3 = load_model(model3_name)

def generate_response(model, tokenizer, prompt):
    """Generate model response"""
    messages = [{"role": "user", "content": prompt}]
    inputs = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        return_tensors="pt"
    ).to(model.device)

    attention_mask = torch.ones_like(inputs).to(model.device)

    outputs = model.generate(
        inputs,
        attention_mask=attention_mask,
        max_new_tokens=256,
        temperature=0.7,
        do_sample=True
    )

    return tokenizer.decode(outputs[0][len(inputs[0]):], skip_special_tokens=True)

def evaluate_response(generated, reference):
    """Evaluate generated response"""
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    rouge_scores = scorer.score(reference, generated)

    return {
        'rouge1': rouge_scores['rouge1'].fmeasure,
        'rouge2': rouge_scores['rouge2'].fmeasure,
        'rougeL': rouge_scores['rougeL'].fmeasure
    }

# Test cases remain the same
test_cases = [
    {
        'prompt': 'Summarize the following text: "Climate change is a global environmental crisis. Rising temperatures are causing polar ice caps to melt, leading to rising sea levels. This threatens coastal communities and marine ecosystems. Additionally, extreme weather events are becoming more frequent and intense, causing widespread damage and displacement. Scientists warn that immediate action is necessary to prevent catastrophic consequences."',
        'reference': 'Climate change is causing rising temperatures and melting ice caps, resulting in rising sea levels and threats to coastal areas. Extreme weather events are increasing, and immediate action is needed to prevent severe consequences.'
    },
    {
        'prompt': 'Explain how social media has changed modern communication in 2-3 sentences.',
        'reference': 'Social media has revolutionized modern communication by enabling instant global connectivity and information sharing. It has created new ways for people to connect, share experiences, and form communities regardless of geographical boundaries.'
    },
    {
        'prompt': 'Describe the process of photosynthesis in simple terms.',
        'reference': 'Photosynthesis is the process where plants convert sunlight into energy. They use this energy, along with water and carbon dioxide, to create glucose and oxygen. This process is essential for plant growth and provides oxygen for other living things.'
    },
    {
        'prompt': 'Give a brief overview of the Industrial Revolution and its main impacts.',
        'reference': 'The Industrial Revolution marked a major shift from manual production to machine manufacturing, primarily during the 18th and 19th centuries. It led to significant technological, economic, and social changes, including urbanization, improved manufacturing processes, and new working conditions. This period fundamentally transformed how people lived and worked.'
    }
]

# Initialize arrays to store results from multiple runs
num_runs = 3
all_scores_1 = []
all_scores_2 = []
all_scores_3 = []

print(f"Starting evaluation with {num_runs} runs...")
for run in range(num_runs):
    print(f"\nRun {run + 1}/{num_runs}")
    run_results = []

    for test_case in test_cases:
        prompt = test_case['prompt']
        reference = test_case['reference']

        print(f"\nProcessing task: {prompt[:50]}...")
        response1 = generate_response(model1, tokenizer1, prompt)
        response2 = generate_response(model2, tokenizer2, prompt)
        response3 = generate_response(model3, tokenizer3, prompt)

        scores1 = evaluate_response(response1, reference)
        scores2 = evaluate_response(response2, reference)
        scores3 = evaluate_response(response3, reference)

        run_results.append({
            'prompt': prompt,
            'reference': reference,
            'model1_response': response1,
            'model2_response': response2,
            'model3_response': response3,
            'model1_scores': scores1,
            'model2_scores': scores2,
            'model3_scores': scores3
        })

    # Calculate average scores for this run
    run_avg_1 = {metric: np.mean([r['model1_scores'][metric] for r in run_results])
                for metric in ['rouge1', 'rouge2', 'rougeL']}
    run_avg_2 = {metric: np.mean([r['model2_scores'][metric] for r in run_results])
                for metric in ['rouge1', 'rouge2', 'rougeL']}
    run_avg_3 = {metric: np.mean([r['model3_scores'][metric] for r in run_results])
                for metric in ['rouge1', 'rouge2', 'rougeL']}

    all_scores_1.append(run_avg_1)
    all_scores_2.append(run_avg_2)
    all_scores_3.append(run_avg_3)

    # Print detailed results for this run
    print(f"\n=== Detailed Results for Run {run + 1} ===")
    for idx, result in enumerate(run_results):
        print(f"\nTest Case {idx + 1}:")
        print(f"Task: {result['prompt'][:100]}...")
        print(f"Reference: {result['reference']}")
        print(f"\nModel 1 response: {result['model1_response']}")
        print(f"Model 1 scores: {result['model1_scores']}")
        print(f"\nModel 2 response: {result['model2_response']}")
        print(f"Model 2 scores: {result['model2_scores']}")
        print(f"\nModel 3 response: {result['model3_response']}")
        print(f"Model 3 scores: {result['model3_scores']}")

# Calculate final average scores across all runs
final_avg_1 = {
    metric: np.mean([run[metric] for run in all_scores_1])
    for metric in ['rouge1', 'rouge2', 'rougeL']
}
final_avg_2 = {
    metric: np.mean([run[metric] for run in all_scores_2])
    for metric in ['rouge1', 'rouge2', 'rougeL']
}
final_avg_3 = {
    metric: np.mean([run[metric] for run in all_scores_3])
    for metric in ['rouge1', 'rouge2', 'rougeL']
}

print("\n=== Final Average Scores (Across All Runs) ===")
print(f"Model 1 ({model1_name}) final average scores: {final_avg_1}")
print(f"Model 2 ({model2_name}) final average scores: {final_avg_2}")
print(f"Model 3 ({model3_name}) final average scores: {final_avg_3}")

# Calculate and print standard deviations
std_1 = {
    metric: np.std([run[metric] for run in all_scores_1])
    for metric in ['rouge1', 'rouge2', 'rougeL']
}
std_2 = {
    metric: np.std([run[metric] for run in all_scores_2])
    for metric in ['rouge1', 'rouge2', 'rougeL']
}
std_3 = {
    metric: np.std([run[metric] for run in all_scores_3])
    for metric in ['rouge1', 'rouge2', 'rougeL']
}

print("\n=== Standard Deviations ===")
print(f"Model 1 ({model1_name}) score standard deviations: {std_1}")
print(f"Model 2 ({model2_name}) score standard deviations: {std_2}")
print(f"Model 3 ({model3_name}) score standard deviations: {std_3}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# loading lemongooooo/lora_data_0...
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.46.3.
#    \\   /|    GPU: NVIDIA L4. Max memory: 22.168 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 8.9. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# finish
# loading lemongooooo/lora_data_200k...
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.46.3.
#    \\   /|    GPU: NVIDIA L4. Max memory: 22.168 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 8.9. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# finish
# loading lemongooooo/lora_data_300k...
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.46.3.
#    \\   /|    GPU: NVIDIA L4. Max memory: 22.168 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 8.9. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# finish
# Starting evaluation with 3 runs...
#
# Run 1/3
#
# Processing task: Summarize the following text: "Climate change is a...
#
# Processing task: Explain how social media has changed modern commun...
#
# Processing task: Describe the process of photosynthesis in simple t...
#
# Processing task: Give a brief overview of the Industrial Revolution...
#
# === Detailed Results for Run 1 ===
#
# Test Case 1:
# Task: Summarize the following text: "Climate change is a global environmental crisis. Rising temperatures ...
# Reference: Climate change is causing rising temperatures and melting ice caps, resulting in rising sea levels and threats to coastal areas. Extreme weather events are increasing, and immediate action is needed to prevent severe consequences.
#
# Model 1 response: Climate change is a global environmental crisis that affects the environment, coastal communities, and marine ecosystems. It leads to rising sea levels and more frequent and intense extreme weather events, causing widespread damage and displacement. Scientists warn that immediate action is necessary to prevent catastrophic consequences.
# Model 1 scores: {'rouge1': 0.5249999999999999, 'rouge2': 0.2564102564102564, 'rougeL': 0.45}
#
# Model 2 response: Climate change is a global environmental crisis that is causing polar ice caps to melt and sea levels to rise. This is threatening coastal communities and marine ecosystems, as well as causing more frequent and intense extreme weather events that lead to widespread damage and displacement. Scientists emphasize the need for immediate action to prevent catastrophic consequences.
# Model 2 scores: {'rouge1': 0.5494505494505495, 'rouge2': 0.20224719101123598, 'rougeL': 0.4175824175824176}
#
# Model 3 response: Climate change is a global environmental crisis that involves rising temperatures and melting polar ice caps, leading to rising sea levels and threatening coastal communities and marine ecosystems. Scientists also warn that extreme weather events are becoming more frequent and intense, causing widespread damage and displacement. Immediate action is necessary to prevent catastrophic consequences.
# Model 3 scores: {'rouge1': 0.6136363636363636, 'rouge2': 0.3488372093023256, 'rougeL': 0.5681818181818182}
#
# Test Case 2:
# Task: Explain how social media has changed modern communication in 2-3 sentences....
# Reference: Social media has revolutionized modern communication by enabling instant global connectivity and information sharing. It has created new ways for people to connect, share experiences, and form communities regardless of geographical boundaries.
#
# Model 1 response: Social media has revolutionized modern communication by providing a platform for individuals to connect with others across the globe instantly. It has enabled instant sharing of thoughts, ideas, and experiences through various platforms such as Facebook, Instagram, and Twitter. This has transformed the way we communicate, making it more interactive, visual, and accessible.
# Model 1 scores: {'rouge1': 0.49411764705882355, 'rouge2': 0.21686746987951808, 'rougeL': 0.3294117647058824}
#
# Model 2 response: Social media has revolutionized modern communication by providing a platform for instant communication, information sharing, and community building. It has enabled people to connect with others globally, access a vast amount of information, and engage in various forms of content, such as videos, images, and live streams. Additionally, social media platforms have also changed the way we interact with each other, as they provide a space for real-time conversations, discussions, and debates.
# Model 2 scores: {'rouge1': 0.45714285714285713, 'rouge2': 0.1941747572815534, 'rougeL': 0.34285714285714286}
#
# Model 3 response: Social media has revolutionized the way people communicate, transforming the traditional forms of face-to-face and written communication into a digital landscape. It has enabled instant connections, global interactions, and the dissemination of information on a scale that was previously unimaginable. This has led to new challenges and opportunities, such as the spread of misinformation and the blurring of personal and public boundaries.
# Model 3 scores: {'rouge1': 0.4583333333333333, 'rouge2': 0.10638297872340426, 'rougeL': 0.3125}
#
# Test Case 3:
# Task: Describe the process of photosynthesis in simple terms....
# Reference: Photosynthesis is the process where plants convert sunlight into energy. They use this energy, along with water and carbon dioxide, to create glucose and oxygen. This process is essential for plant growth and provides oxygen for other living things.
#
# Model 1 response: Photosynthesis is the process by which plants, algae, and some bacteria make their own food. This food is called glucose, and it gives them the energy they need to grow and survive. The process happens when plants are exposed to sunlight, carbon dioxide, and water. Here's a simplified explanation of how it works:
#
# 1. The plant absorbs carbon dioxide from the air through its leaves.
# 2. The plant absorbs water from the soil through its roots.
# 3. The plant uses sunlight to convert the carbon dioxide and water into glucose, which is a type of sugar.
# 4. The glucose is then used by the plant to grow and develop.
#
# Photosynthesis is essential for life on Earth because it helps plants grow and thrive, which in turn supports all the living organisms that depend on them for food and shelter.
# Model 1 scores: {'rouge1': 0.3016759776536313, 'rouge2': 0.09039548022598871, 'rougeL': 0.21229050279329603}
#
# Model 2 response: Photosynthesis is a process that plants use to make food from sunlight. Here's a simple explanation of how it works:
#
# 1. Plants use their leaves to catch sunlight. This sunlight is used to power a chemical reaction inside the plant.
# 2. The plant takes in carbon dioxide from the air around it.
# 3. The plant uses the energy from the sunlight to convert the carbon dioxide and water (from the soil) into a type of sugar that gives the plant energy.
# 4. This sugar is used by the plant to grow and thrive.
# 5. As a byproduct of photosynthesis, the plant releases oxygen into the air. This oxygen is what humans and other animals need to breathe.
#
# In summary, photosynthesis is how plants make food from sunlight and release oxygen into the air, which is essential for many living things.
# Model 2 scores: {'rouge1': 0.3222222222222222, 'rouge2': 0.056179775280898875, 'rougeL': 0.23333333333333334}
#
# Model 3 response: Photosynthesis is the process by which plants, algae, and some bacteria make their own food from sunlight. Here's a simplified explanation:
#
# 1. Plants absorb carbon dioxide from the air through tiny openings called stomata.
# 2. They also absorb water from the soil through their roots.
# 3. The plant uses sunlight (energy from the sun) to convert the carbon dioxide and water into a type of sugar called glucose.
# 4. This glucose is used as food for the plant, providing energy for growth and development.
# 5. At the same time, the plant releases oxygen into the air as a byproduct of photosynthesis.
#
# Photosynthesis is an essential process that helps plants grow and thrive, and it also contributes to the oxygen in the air that humans and other animals need to breathe.
# Model 3 scores: {'rouge1': 0.3764705882352941, 'rouge2': 0.05952380952380953, 'rougeL': 0.23529411764705882}
#
# Test Case 4:
# Task: Give a brief overview of the Industrial Revolution and its main impacts....
# Reference: The Industrial Revolution marked a major shift from manual production to machine manufacturing, primarily during the 18th and 19th centuries. It led to significant technological, economic, and social changes, including urbanization, improved manufacturing processes, and new working conditions. This period fundamentally transformed how people lived and worked.
#
# Model 1 response: The Industrial Revolution was a significant transformation that occurred in the late 18th and early 19th centuries, leading to the development of new technologies and the shift from manual labor to machine-based manufacturing. This period of rapid industrialization had a profound impact on the way people lived, worked, and communicated. The main impacts of the Industrial Revolution were:
#
# 1. Increased productivity: The Industrial Revolution introduced new machines and technologies that allowed for mass production and increased efficiency. This led to a significant increase in productivity and output, as well as the growth of industries such as textiles, steel, and coal mining.
#
# 2. Changes in the social structure: The Industrial Revolution led to the growth of cities and the development of a new class of industrialists and entrepreneurs. This led to changes in the social structure, as traditional industries and jobs were replaced by new industries and jobs.
#
# 3. Improved living standards: The Industrial Revolution led to an increase in the standard of living for many people, as new technologies and machines made it possible to produce goods more quickly and efficiently. This led to an increase in the availability of goods and services, and a reduction in the cost of living.
#
# 4. Environmental impact: The Industrial Revolution led to a significant increase in the amount of pollution in the air and water,
# Model 1 scores: {'rouge1': 0.2518518518518519, 'rouge2': 0.07462686567164178, 'rougeL': 0.17037037037037037}
#
# Model 2 response: The Industrial Revolution was a major economic and technological transformation that occurred in the 18th and 19th centuries, primarily in Europe and North America. It was characterized by the widespread use of machines and factories to produce goods, replacing traditional crafts and artisanal production methods. The main impacts of the Industrial Revolution were:
#
# 1. Economic growth: The Industrial Revolution led to significant economic growth, as new machines and factories increased production efficiency and productivity. This led to an increase in the availability of goods and services, and a rise in the standard of living for many people.
#
# 2. Urbanization: As people moved from rural areas to cities to work in factories, urbanization increased. Cities became centers of industry and commerce, and the population grew rapidly.
#
# 3. Environmental degradation: The Industrial Revolution led to significant environmental degradation, as the use of fossil fuels and the release of pollutants into the atmosphere caused air and water pollution. This had negative impacts on the environment and human health.
#
# 4. Social changes: The Industrial Revolution led to significant social changes, as the rise of a new industrial working class led to the emergence of a new class system. The working class had limited rights and opportunities, and the gap between the wealthy and the poor grew wider.
#
# 5. Technological advancements: The Industrial
# Model 2 scores: {'rouge1': 0.25660377358490566, 'rouge2': 0.08365019011406843, 'rougeL': 0.15849056603773587}
#
# Model 3 response: The Industrial Revolution was a period of significant economic, social, and technological change that began in Britain in the late 18th century and spread to other parts of the world over the next century. It was characterized by the development and widespread use of mechanized factories, the introduction of new manufacturing technologies, and the expansion of trade and commerce.
#
# The Industrial Revolution had a number of main impacts on society. One of the most significant was the growth of industry and the economy. The development of new manufacturing technologies and the expansion of trade and commerce helped to increase production and improve efficiency, leading to economic growth and the creation of new industries.
#
# Another major impact of the Industrial Revolution was the development of new social classes. The growth of industry created a new class of workers, known as industrial laborers, who were employed in factories and mills. This class was distinct from the traditional aristocracy and the emerging middle class, and it was characterized by low wages, long working hours, and poor working conditions.
#
# The Industrial Revolution also had significant impacts on the environment. The development of new manufacturing technologies and the expansion of industry helped to increase air and water pollution, and the use of coal and other fossil fuels helped to contribute to climate change.
#
# Overall, the Industrial Revolution was a significant period of change that
# Model 3 scores: {'rouge1': 0.2246376811594203, 'rouge2': 0.029197080291970802, 'rougeL': 0.13043478260869565}
#
# Run 2/3
#
# Processing task: Summarize the following text: "Climate change is a...
#
# Processing task: Explain how social media has changed modern commun...
#
# Processing task: Describe the process of photosynthesis in simple t...
#
# Processing task: Give a brief overview of the Industrial Revolution...
#
# === Detailed Results for Run 2 ===
#
# Test Case 1:
# Task: Summarize the following text: "Climate change is a global environmental crisis. Rising temperatures ...
# Reference: Climate change is causing rising temperatures and melting ice caps, resulting in rising sea levels and threats to coastal areas. Extreme weather events are increasing, and immediate action is needed to prevent severe consequences.
#
# Model 1 response: Climate change is a global crisis that affects the environment and human communities. Rising temperatures are causing ice caps to melt, leading to rising sea levels and threatening coastal communities and marine ecosystems. Extreme weather events are becoming more frequent and intense, causing damage and displacement. Scientists warn that immediate action is necessary to prevent catastrophic consequences.
# Model 1 scores: {'rouge1': 0.5934065934065933, 'rouge2': 0.2921348314606742, 'rougeL': 0.5054945054945055}
#
# Model 2 response: Climate change is a global environmental crisis. It is causing polar ice caps to melt, leading to rising sea levels, which threatens coastal communities and marine ecosystems. Extreme weather events are becoming more frequent and intense, causing widespread damage and displacement. Scientists warn that immediate action is necessary to prevent catastrophic consequences.
# Model 2 scores: {'rouge1': 0.5813953488372092, 'rouge2': 0.2857142857142857, 'rougeL': 0.48837209302325585}
#
# Model 3 response: Climate change is a global crisis that threatens the planet, causing polar ice caps to melt and sea levels to rise, which puts coastal communities and marine ecosystems at risk. Scientists warn that immediate action is necessary to prevent catastrophic consequences.
# Model 3 scores: {'rouge1': 0.5333333333333332, 'rouge2': 0.1917808219178082, 'rougeL': 0.45333333333333337}
#
# Test Case 2:
# Task: Explain how social media has changed modern communication in 2-3 sentences....
# Reference: Social media has revolutionized modern communication by enabling instant global connectivity and information sharing. It has created new ways for people to connect, share experiences, and form communities regardless of geographical boundaries.
#
# Model 1 response: Social media has revolutionized the way people communicate, enabling instant and global connectivity. Platforms like Facebook, Twitter, and Instagram have created new avenues for self-expression, networking, and information sharing. As a result, traditional forms of communication, such as phone calls and face-to-face interactions, have become less common, leading to a more ephemeral and virtualized form of social interaction.
# Model 1 scores: {'rouge1': 0.4731182795698925, 'rouge2': 0.17582417582417584, 'rougeL': 0.3655913978494624}
#
# Model 2 response: Social media has revolutionized modern communication by enabling rapid and global connectivity through platforms such as Facebook, Twitter, and Instagram. These platforms allow individuals to share thoughts, opinions, and experiences with a vast audience, fostering a sense of community and exchange. As a result, the way we communicate has shifted from personal and intimate to more public and interactive.
# Model 2 scores: {'rouge1': 0.41758241758241754, 'rouge2': 0.1797752808988764, 'rougeL': 0.3516483516483517}
#
# Model 3 response: Social media has revolutionized modern communication by providing a platform for instant, global connections and information exchange. It has transformed the way people interact, share ideas, and consume content, often in real-time and with unprecedented reach and accessibility. As a result, traditional forms of communication such as letters and face-to-face conversations have become less common, and new forms of expression and discourse have emerged.
# Model 3 scores: {'rouge1': 0.48484848484848486, 'rouge2': 0.22680412371134023, 'rougeL': 0.42424242424242425}
#
# Test Case 3:
# Task: Describe the process of photosynthesis in simple terms....
# Reference: Photosynthesis is the process where plants convert sunlight into energy. They use this energy, along with water and carbon dioxide, to create glucose and oxygen. This process is essential for plant growth and provides oxygen for other living things.
#
# Model 1 response: Photosynthesis is a process that plants, algae, and some bacteria use to make their own food from sunlight, water, and carbon dioxide. Here's how it works:
#
# 1. First, plants absorb water through their roots and take in carbon dioxide from the air through their leaves.
# 2. Next, they use energy from sunlight to convert the carbon dioxide and water into a type of sugar called glucose.
# 3. At the same time, they release oxygen into the air as a byproduct of photosynthesis.
# 4. This process happens in specialized parts of the plant called chloroplasts, which are filled with tiny molecules called chlorophyll. Chlorophyll helps plants absorb sunlight and use it to power photosynthesis.
# 5. The glucose produced during photosynthesis is used by the plant to grow and develop, while the oxygen is released into the air for animals and humans to breathe.
#
# In short, photosynthesis is how plants make their own food from sunlight, water, and carbon dioxide, and it's also how they produce oxygen, which is essential for life on Earth.
# Model 1 scores: {'rouge1': 0.27230046948356806, 'rouge2': 0.07582938388625593, 'rougeL': 0.18779342723004694}
#
# Model 2 response: Photosynthesis is the process by which plants, algae, and some bacteria make their own food from sunlight, water, and carbon dioxide. The process involves the following steps:
#
# 1. Plants absorb water and carbon dioxide from the air through their roots and leaves.
# 2. They use energy from sunlight to convert carbon dioxide and water into glucose, a type of sugar that provides energy for the plant.
# 3. The glucose is stored in the plant's cells and used as a source of energy when needed.
# 4. The oxygen that is produced as a byproduct of photosynthesis is released into the air.
#
# Overall, photosynthesis is a critical process that allows plants to grow and thrive, and it also helps to remove carbon dioxide from the atmosphere, which can help to regulate the Earth's climate.
# Model 2 scores: {'rouge1': 0.30057803468208094, 'rouge2': 0.08187134502923976, 'rougeL': 0.19653179190751444}
#
# Model 3 response: Photosynthesis is a process that plants use to make their own food using sunlight. Here's how it works:
#
# 1. Plants spread out their leaves to catch the sunlight. This sunlight is used to power a chemical reaction called photosynthesis.
#
# 2. The leaves of plants have tiny little factories called chloroplasts inside them. Chloroplasts contain a special green pigment called chlorophyll, which helps plants absorb the sunlight.
#
# 3. When plants absorb sunlight, they also absorb carbon dioxide from the air and water from the ground. These three things (sunlight, carbon dioxide, and water) are combined in the chloroplasts to make a type of sugar called glucose.
#
# 4. Plants use this sugar as their food. They can use it to grow and develop, and it also gives them the energy they need to move around and respond to their environment.
#
# So, photosynthesis is basically how plants make their own food using sunlight, carbon dioxide, and water. It's a very important process that helps plants grow and thrive.
# Model 3 scores: {'rouge1': 0.22330097087378642, 'rouge2': 0.03921568627450981, 'rougeL': 0.15533980582524273}
#
# Test Case 4:
# Task: Give a brief overview of the Industrial Revolution and its main impacts....
# Reference: The Industrial Revolution marked a major shift from manual production to machine manufacturing, primarily during the 18th and 19th centuries. It led to significant technological, economic, and social changes, including urbanization, improved manufacturing processes, and new working conditions. This period fundamentally transformed how people lived and worked.
#
# Model 1 response: The Industrial Revolution was a period of significant technological and social change that took place in the 18th and 19th centuries, primarily in Europe and North America. It marked the shift from manual labor to machine-based manufacturing, which led to the development of factories, mass production, and the growth of cities. Some of the main impacts of the Industrial Revolution include:
#
# 1. Economic growth: The Industrial Revolution led to the growth of industries, the creation of new jobs, and an increase in economic productivity. This led to an increase in the standard of living for many people.
#
# 2. Urbanization: As people moved from the countryside to cities in search of work, the population of cities grew rapidly. This led to the development of new social systems, including the growth of cities and the development of public services such as water, sewage, and transportation.
#
# 3. Social changes: The Industrial Revolution also led to significant social changes, including the growth of the middle class and the decline of the feudal system. This led to the development of new social systems, including the growth of democracy and the rights of workers.
#
# 4. Environmental impact: The Industrial Revolution also had a significant environmental impact, including the pollution of air and water, the destruction of natural habitats, and the depletion of natural resources
# Model 1 scores: {'rouge1': 0.2781954887218045, 'rouge2': 0.11363636363636363, 'rougeL': 0.16541353383458646}
#
# Model 2 response: The Industrial Revolution was a transformative period in history that marked a shift from manual labor to machine-based manufacturing. It began in Britain in the late 18th century and spread to other parts of the world over the next century. The main impacts of the Industrial Revolution were:
#
# 1. Economic growth: The Industrial Revolution led to the development of new industries and the creation of a large middle class. It also increased productivity and efficiency, leading to economic growth and the emergence of capitalism as a dominant economic system.
#
# 2. Social change: The Industrial Revolution led to the development of new social structures and the growth of cities. It also led to the emergence of a new working class that was dependent on machines for their livelihood.
#
# 3. Environmental impact: The Industrial Revolution led to the development of new technologies and the increase in industrial production. However, this led to the pollution of the environment and the depletion of natural resources.
#
# 4. Cultural change: The Industrial Revolution led to the development of new cultural forms and the emergence of a new urban culture. It also led to the growth of a new form of entertainment, such as cinema and television.
#
# 5. Globalization: The Industrial Revolution led to the development of new technologies and the emergence of global trade. It also led to the growth of international relations
# Model 2 scores: {'rouge1': 0.2327272727272727, 'rouge2': 0.06593406593406594, 'rougeL': 0.1890909090909091}
#
# Model 3 response: The Industrial Revolution was a period of significant technological, economic, and social change that began in Britain in the 18th century and spread to other parts of the world. The revolution marked the transition from manual labor to machine-based manufacturing, which had profound impacts on society, economy, and politics. Here are some of the main impacts of the Industrial Revolution:
#
# 1. **Technological Innovations**: The Industrial Revolution was characterized by the development of new technologies, such as the steam engine, power looms, and the telegraph. These innovations enabled mass production, increased efficiency, and facilitated communication over long distances.
#
# 2. **Economic Growth**: The Industrial Revolution led to significant economic growth. The development of new industries, such as textiles, iron, and coal mining, created new jobs and increased the production of goods. This growth was accompanied by the rise of capitalism, where businesses were driven by profit motive.
#
# 3. **Urbanization**: As people moved from rural areas to cities to work in the new factories, urbanization occurred. Cities grew rapidly, leading to the development of new infrastructure and the growth of urban centers.
#
# 4. **Social Changes**: The Industrial Revolution brought about significant social changes. The rise of the middle class, created by the growth of industry, led to
# Model 3 scores: {'rouge1': 0.246031746031746, 'rouge2': 0.10399999999999998, 'rougeL': 0.15873015873015872}
#
# Run 3/3
#
# Processing task: Summarize the following text: "Climate change is a...
#
# Processing task: Explain how social media has changed modern commun...
#
# Processing task: Describe the process of photosynthesis in simple t...
#
# Processing task: Give a brief overview of the Industrial Revolution...
#
# === Detailed Results for Run 3 ===
#
# Test Case 1:
# Task: Summarize the following text: "Climate change is a global environmental crisis. Rising temperatures ...
# Reference: Climate change is causing rising temperatures and melting ice caps, resulting in rising sea levels and threats to coastal areas. Extreme weather events are increasing, and immediate action is needed to prevent severe consequences.
#
# Model 1 response: Climate change is a global environmental crisis causing polar ice caps to melt, resulting in rising sea levels and threatening coastal communities and marine ecosystems. It is also leading to more frequent and intense extreme weather events, causing widespread damage and displacement. Scientists stress the need for immediate action to prevent catastrophic consequences.
# Model 1 scores: {'rouge1': 0.6206896551724137, 'rouge2': 0.28235294117647064, 'rougeL': 0.5057471264367817}
#
# Model 2 response: Climate change is a global environmental crisis that causes polar ice caps to melt, resulting in rising sea levels and threatening coastal communities and marine ecosystems. Extreme weather events are becoming more frequent and intense, causing widespread damage and displacement. Scientists emphasize the need for immediate action to prevent catastrophic consequences.
# Model 2 scores: {'rouge1': 0.6352941176470589, 'rouge2': 0.3132530120481928, 'rougeL': 0.5411764705882354}
#
# Model 3 response: Climate change is a global environmental crisis characterized by rising temperatures and melting polar ice caps, leading to increased sea levels and coastal flooding. This poses significant threats to coastal communities and marine ecosystems, and scientists emphasize the need for immediate action to prevent severe consequences.
# Model 3 scores: {'rouge1': 0.6, 'rouge2': 0.3589743589743589, 'rougeL': 0.55}
#
# Test Case 2:
# Task: Explain how social media has changed modern communication in 2-3 sentences....
# Reference: Social media has revolutionized modern communication by enabling instant global connectivity and information sharing. It has created new ways for people to connect, share experiences, and form communities regardless of geographical boundaries.
#
# Model 1 response: Social media has revolutionized modern communication by providing platforms for instant global connectivity, allowing people to share their thoughts and ideas with a vast audience. It has also enabled the creation of online communities centered around shared interests, fostering relationships and networking opportunities. Additionally, social media has made it easier to engage in real-time conversations and stay informed about current events.
# Model 1 scores: {'rouge1': 0.48936170212765956, 'rouge2': 0.21739130434782608, 'rougeL': 0.3191489361702127}
#
# Model 2 response: Social media has revolutionized modern communication by providing a platform for people to connect and interact with each other instantly, regardless of geographical location. It has also enabled instant sharing and dissemination of information, allowing for global awareness and rapid response to events. Overall, social media has transformed the way we communicate, making it faster, more accessible, and more interactive.
# Model 2 scores: {'rouge1': 0.5434782608695653, 'rouge2': 0.3111111111111111, 'rougeL': 0.32608695652173914}
#
# Model 3 response: Social media has revolutionized the way we communicate by providing a platform for instant sharing of thoughts, ideas, and experiences with a global audience. It has transformed the way we interact with each other, making it possible to connect with people across different geographical locations and cultures. Additionally, social media has also changed the way we consume and interact with information, with many people now relying on social media platforms as their primary source of news and information.
# Model 3 scores: {'rouge1': 0.4, 'rouge2': 0.12962962962962962, 'rougeL': 0.2727272727272727}
#
# Test Case 3:
# Task: Describe the process of photosynthesis in simple terms....
# Reference: Photosynthesis is the process where plants convert sunlight into energy. They use this energy, along with water and carbon dioxide, to create glucose and oxygen. This process is essential for plant growth and provides oxygen for other living things.
#
# Model 1 response: Photosynthesis is a process that plants and some other organisms use to turn sunlight into energy. Here's a simple breakdown of how it works:
#
# 1. Plants take in carbon dioxide from the air through tiny openings on their leaves called stomata.
# 2. They also take in water from the soil through their roots.
# 3. The plant's leaves have special green cells that contain a pigment called chlorophyll. This pigment absorbs sunlight.
# 4. The absorbed sunlight gives the plant energy, which it uses to convert the carbon dioxide and water into glucose and oxygen.
# 5. The glucose is used by the plant to grow and develop, while the oxygen is released into the air.
#
# In short, photosynthesis is how plants make their own food using sunlight, water, and carbon dioxide.
# Model 1 scores: {'rouge1': 0.30588235294117644, 'rouge2': 0.09523809523809523, 'rougeL': 0.2235294117647059}
#
# Model 2 response: Photosynthesis is a process in which plants use sunlight to convert carbon dioxide and water into glucose and oxygen. Here's a simplified explanation:
#
# 1. Plants absorb carbon dioxide from the air through tiny openings called stomata.
# 2. They also absorb water from the soil through their roots.
# 3. When sunlight hits a molecule of carbon dioxide and water, it creates a chemical reaction called photosynthesis.
# 4. This reaction converts carbon dioxide and water into glucose (a type of sugar) and oxygen.
# 5. Plants use the glucose as energy to grow and develop.
# 6. Oxygen is released into the air as a byproduct of photosynthesis.
#
# In summary, photosynthesis is a way in which plants use sunlight to create energy and produce oxygen as a byproduct.
# Model 2 scores: {'rouge1': 0.3170731707317073, 'rouge2': 0.0617283950617284, 'rougeL': 0.2195121951219512}
#
# Model 3 response: Photosynthesis is a process by which plants and some other organisms make their own food using sunlight. Here's a simple breakdown of how it works:
#
# 1. Plants use sunlight to make a type of sugar called glucose, which is a source of energy for them. This process is called the light-dependent reactions.
#
# 2. Plants take in carbon dioxide from the air around them and water from the soil. This is done through tiny openings called stomata on their leaves. This is called the light-independent reactions, or the Calvin cycle.
#
# 3. The energy from sunlight is used to convert carbon dioxide and water into glucose and oxygen. The glucose is used for energy and growth, while the oxygen is released into the air.
#
# So, to summarize, photosynthesis is the process by which plants and some other organisms make their own food using sunlight, carbon dioxide, and water.
# Model 3 scores: {'rouge1': 0.3191489361702127, 'rouge2': 0.08602150537634409, 'rougeL': 0.19148936170212766}
#
# Test Case 4:
# Task: Give a brief overview of the Industrial Revolution and its main impacts....
# Reference: The Industrial Revolution marked a major shift from manual production to machine manufacturing, primarily during the 18th and 19th centuries. It led to significant technological, economic, and social changes, including urbanization, improved manufacturing processes, and new working conditions. This period fundamentally transformed how people lived and worked.
#
# Model 1 response: The Industrial Revolution was a period of significant economic and technological change in the late 18th and early 19th centuries. It marked the transition from manual labor to machine-based manufacturing, leading to the development of new industries and the growth of urban centers. The Industrial Revolution had a profound impact on society, including:
#
# 1. Increased productivity: The introduction of new machines and technologies led to a significant increase in productivity, as workers could now produce more goods in a shorter amount of time.
#
# 2. Urbanization: As people moved from the countryside to cities in search of work, urban centers grew rapidly. This led to the development of new social structures and institutions.
#
# 3. Changes in social class: The Industrial Revolution created new social classes, including the middle class, which was made up of business owners and managers.
#
# 4. Environmental impact: The Industrial Revolution had a significant impact on the environment, as the increased use of fossil fuels led to air and water pollution.
#
# 5. Improved standard of living: The Industrial Revolution led to an increase in the standard of living for many people, as goods became cheaper and more widely available.
#
# Overall, the Industrial Revolution was a significant period of change in human history, with far-reaching impacts on society, the economy, and the environment.
# Model 1 scores: {'rouge1': 0.2737642585551331, 'rouge2': 0.0689655172413793, 'rougeL': 0.1596958174904943}
#
# Model 2 response: The Industrial Revolution was a transformative period in human history, beginning in the 18th century and lasting until the late 19th century. It was characterized by the development and widespread adoption of new technologies, particularly steam power, the factory system, and mechanization. The main impacts of the Industrial Revolution were:
#
# 1. Economic growth: The Industrial Revolution led to the development of capitalism, the growth of industry, and the emergence of a new middle class. It created new opportunities for economic growth and increased productivity.
#
# 2. Urbanization: The Industrial Revolution led to the growth of cities as people moved from rural areas to work in factories. This led to the development of new urban cultures and the growth of cities.
#
# 3. Environmental degradation: The Industrial Revolution led to the development of new technologies that produced large amounts of pollution and waste. This led to environmental degradation and the loss of natural resources.
#
# 4. Social inequality: The Industrial Revolution led to the growth of a new class of industrialists and the widening of the gap between the rich and the poor. This led to social inequality and the emergence of social movements to address these issues.
#
# 5. Changes in family structures: The Industrial Revolution led to changes in family structures, particularly the growth of nuclear families and the decline of extended family structures
# Model 2 scores: {'rouge1': 0.2164179104477612, 'rouge2': 0.045112781954887216, 'rougeL': 0.1417910447761194}
#
# Model 3 response: The Industrial Revolution, which spanned from the late 18th to the mid-19th century, was a transformative period in human history. It marked a significant shift from manual labor to machine-based manufacturing, which had profound impacts on society, economy, and technology.
#
# The Industrial Revolution began in Britain in the late 18th century and soon spread to other parts of Europe and North America. It was characterized by the development and widespread adoption of new technologies such as the steam engine, textile machines, and iron production.
#
# The main impacts of the Industrial Revolution were:
#
# 1. **Increased productivity**: Machines and factories allowed for mass production, increasing productivity and efficiency. This led to an increase in goods and services, which in turn contributed to economic growth.
#
# 2. **Urbanization**: As people moved from rural areas to cities to work in factories, urbanization became a significant phenomenon. Cities like Manchester, Birmingham, and Liverpool in Britain became hubs of industrial activity.
#
# 3. **Social changes**: The Industrial Revolution brought about changes in social dynamics, including the rise of a new industrial working class and the growth of cities, which led to the development of new social systems and institutions.
#
# 4. **Economic growth**: The Industrial Revolution was a key factor in the economic growth of the period
# Model 3 scores: {'rouge1': 0.2879377431906615, 'rouge2': 0.07058823529411766, 'rougeL': 0.19455252918287935}
#
# === Final Average Scores (Across All Runs) ===
# Model 1 (lemongooooo/lora_data_0) final average scores: {'rouge1': 0.406613689711879, 'rouge2': 0.16330605708322052, 'rougeL': 0.29954056617836206}
# Model 2 (lemongooooo/lora_data_200k) final average scores: {'rouge1': 0.402497161327134, 'rouge2': 0.15672934928667867, 'rougeL': 0.3005394393740588}
# Model 3 (lemongooooo/lora_data_300k) final average scores: {'rouge1': 0.39730659840105303, 'rouge2': 0.1459129532516349, 'rougeL': 0.30390213368175095}
#
# === Standard Deviations ===
# Model 1 (lemongooooo/lora_data_0) score standard deviations: {'rouge1': 0.012062460237992682, 'rouge2': 0.0027209491781234304, 'rougeL': 0.006589846400444577}
# Model 2 (lemongooooo/lora_data_200k) score standard deviations: {'rouge1': 0.01887565738040992, 'rouge2': 0.020042541694700763, 'rougeL': 0.008825194639988432}
# Model 3 (lemongooooo/lora_data_300k) score standard deviations: {'rouge1': 0.019200357106391872, 'rouge2': 0.011034308369727344, 'rougeL': 0.005718697233068255}

# %%
from unsloth import FastLanguageModel
import torch
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
import nltk
import numpy as np

try:
    nltk.download('punkt')
    nltk.download('punkt_tab')
except:
    pass

def load_model(model_name):
    """loading model"""
    print(f"loading {model_name}...")
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name=model_name,
        max_seq_length=2048,
        dtype=torch.float16,
        load_in_4bit=True
    )
    model = FastLanguageModel.for_inference(model)
    print("finish")
    return model, tokenizer

model1_name = "lemongooooo/lora_data_0"
model1, tokenizer1 = load_model(model1_name)

model2_name = "lemongooooo/lora_data_200k"
model2, tokenizer2 = load_model(model2_name)

model3_name = "lemongooooo/lora_data_300k"
model3, tokenizer3 = load_model(model3_name)

def generate_response(model, tokenizer, prompt):
    """Generate model response"""
    messages = [{"role": "user", "content": prompt}]
    inputs = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        return_tensors="pt"
    ).to(model.device)

    attention_mask = torch.ones_like(inputs).to(model.device)

    outputs = model.generate(
        inputs,
        attention_mask=attention_mask,
        max_new_tokens=256,
        temperature=0.7,
        do_sample=True
    )

    return tokenizer.decode(outputs[0][len(inputs[0]):], skip_special_tokens=True)

def evaluate_response(generated, reference):
    """Evaluate generated response using BLEU score"""
    reference_tokens = nltk.word_tokenize(reference.lower())
    generated_tokens = nltk.word_tokenize(generated.lower())

    smoothing = SmoothingFunction().method1

    bleu_score = sentence_bleu([reference_tokens], generated_tokens,
                              weights=(0.25, 0.25, 0.25, 0.25),
                              smoothing_function=smoothing)

    return {'bleu': bleu_score}

# Multilingual translation test cases
test_cases = [
    {
        'prompt': 'Translate to Spanish:\nThe city comes alive at night, with streets filled with music and laughter. Local restaurants serve traditional dishes until late hours.',
        'reference': 'La ciudad cobra vida por la noche, con calles llenas de música y risas. Los restaurantes locales sirven platos tradicionales hasta altas horas.'
    },
    {
        'prompt': 'Translate to French:\nThe art exhibition showcases works from emerging artists around the world. Each piece tells a unique story of cultural heritage.',
        'reference': "L'exposition d'art présente des œuvres d'artistes émergents du monde entier. Chaque pièce raconte une histoire unique d'héritage culturel."
    },
    {
        'prompt': 'Translate to German:\nSustainable energy solutions are becoming increasingly important. Solar and wind power are leading the way in renewable resources.',
        'reference': 'Nachhaltige Energielösungen werden immer wichtiger. Solar- und Windenergie sind führend bei erneuerbaren Ressourcen.'
    },
    {
        'prompt': 'Translate to Italian:\nThe local market offers fresh produce from nearby farms. Visitors can taste seasonal fruits and traditional cheeses.',
        'reference': 'Il mercato locale offre prodotti freschi dalle fattorie vicine. I visitatori possono assaggiare frutta di stagione e formaggi tradizionali.'
    }
]

# Initialize arrays to store results from multiple runs
num_runs = 3
all_scores_1 = []
all_scores_2 = []
all_scores_3 = []

print(f"Starting evaluation with {num_runs} runs...")
for run in range(num_runs):
    print(f"\nRun {run + 1}/{num_runs}")
    run_results = []

    for test_case in test_cases:
        prompt = test_case['prompt']
        reference = test_case['reference']

        print(f"\nProcessing task: {prompt[:50]}...")
        response1 = generate_response(model1, tokenizer1, prompt)
        response2 = generate_response(model2, tokenizer2, prompt)
        response3 = generate_response(model3, tokenizer3, prompt)

        scores1 = evaluate_response(response1, reference)
        scores2 = evaluate_response(response2, reference)
        scores3 = evaluate_response(response3, reference)

        run_results.append({
            'prompt': prompt,
            'reference': reference,
            'model1_response': response1,
            'model2_response': response2,
            'model3_response': response3,
            'model1_scores': scores1,
            'model2_scores': scores2,
            'model3_scores': scores3
        })

    # Calculate average scores for this run
    run_avg_1 = {'bleu': np.mean([r['model1_scores']['bleu'] for r in run_results])}
    run_avg_2 = {'bleu': np.mean([r['model2_scores']['bleu'] for r in run_results])}
    run_avg_3 = {'bleu': np.mean([r['model3_scores']['bleu'] for r in run_results])}

    all_scores_1.append(run_avg_1)
    all_scores_2.append(run_avg_2)
    all_scores_3.append(run_avg_3)

    # Print detailed results for this run
    print(f"\n=== Detailed Results for Run {run + 1} ===")
    for idx, result in enumerate(run_results):
        print(f"\nTest Case {idx + 1}:")
        print(f"Task: {result['prompt'][:100]}...")
        print(f"Reference: {result['reference']}")
        print(f"\nModel 1 response: {result['model1_response']}")
        print(f"Model 1 scores: {result['model1_scores']}")
        print(f"\nModel 2 response: {result['model2_response']}")
        print(f"Model 2 scores: {result['model2_scores']}")
        print(f"\nModel 3 response: {result['model3_response']}")
        print(f"Model 3 scores: {result['model3_scores']}")

# Calculate final average scores across all runs
final_avg_1 = {'bleu': np.mean([run['bleu'] for run in all_scores_1])}
final_avg_2 = {'bleu': np.mean([run['bleu'] for run in all_scores_2])}
final_avg_3 = {'bleu': np.mean([run['bleu'] for run in all_scores_3])}

print("\n=== Final Average Scores (Across All Runs) ===")
print(f"Model 1 ({model1_name}) final average scores: {final_avg_1}")
print(f"Model 2 ({model2_name}) final average scores: {final_avg_2}")
print(f"Model 3 ({model3_name}) final average scores: {final_avg_3}")

# Calculate and print standard deviations
std_1 = {'bleu': np.std([run['bleu'] for run in all_scores_1])}
std_2 = {'bleu': np.std([run['bleu'] for run in all_scores_2])}
std_3 = {'bleu': np.std([run['bleu'] for run in all_scores_3])}

print("\n=== Standard Deviations ===")
print(f"Model 1 ({model1_name}) score standard deviations: {std_1}")
print(f"Model 2 ({model2_name}) score standard deviations: {std_2}")
print(f"Model 3 ({model3_name}) score standard deviations: {std_3}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# loading lemongooooo/lora_data_0...
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.46.3.
#    \\   /|    GPU: NVIDIA L4. Max memory: 22.168 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 8.9. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/54.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/195M [00:00<?, ?B/s]
# Unsloth 2024.12.4 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.
# finish
# loading lemongooooo/lora_data_200k...
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.46.3.
#    \\   /|    GPU: NVIDIA L4. Max memory: 22.168 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 8.9. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# adapter_model.safetensors:   0%|          | 0.00/195M [00:00<?, ?B/s]
# finish
# loading lemongooooo/lora_data_300k...
# ==((====))==  Unsloth 2024.12.4: Fast Llama patching. Transformers:4.46.3.
#    \\   /|    GPU: NVIDIA L4. Max memory: 22.168 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 8.9. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# adapter_model.safetensors:   0%|          | 0.00/195M [00:00<?, ?B/s]
# finish
# Starting evaluation with 3 runs...
#
# Run 1/3
#
# Processing task: Translate to Spanish:
# The city comes alive at nigh...
#
# Processing task: Translate to French:
# The art exhibition showcases ...
#
# Processing task: Translate to German:
# Sustainable energy solutions ...
#
# Processing task: Translate to Italian:
# The local market offers fres...
#
# === Detailed Results for Run 1 ===
#
# Test Case 1:
# Task: Translate to Spanish:
# The city comes alive at night, with streets filled with music and laughter. Lo...
# Reference: La ciudad cobra vida por la noche, con calles llenas de música y risas. Los restaurantes locales sirven platos tradicionales hasta altas horas.
#
# Model 1 response: La ciudad se despierta por la noche, con las calles llenas de música y risas. Los restaurantes locales sirven platos tradicionales hasta las horas más tardías.
# Model 1 scores: {'bleu': 0.6134588734928768}
#
# Model 2 response: La ciudad se vuelve viva por la noche, con calles llenas de música y risas. Los restaurantes locales sirven platos tradicionales hasta las horas tardías.
# Model 2 scores: {'bleu': 0.7012999326891347}
#
# Model 3 response: La ciudad se despierta por la noche, con las calles llenas de música y risas. Los restaurantes locales sirven platos tradicionales hasta altas horas.
# Model 3 scores: {'bleu': 0.766185035460935}
#
# Test Case 2:
# Task: Translate to French:
# The art exhibition showcases works from emerging artists around the world. Each...
# Reference: L'exposition d'art présente des œuvres d'artistes émergents du monde entier. Chaque pièce raconte une histoire unique d'héritage culturel.
#
# Model 1 response: L'exposition d'art présente des œuvres de artistes émergents de tout le monde. Chaque pièce raconte une histoire unique de patrimoine culturel.
# Model 1 scores: {'bleu': 0.44651754110190417}
#
# Model 2 response: L'exposition d'art présente des œuvres de artistes émergents de tout le monde. Chaque pièce raconte une histoire unique de patrimoine culturel.
# Model 2 scores: {'bleu': 0.44651754110190417}
#
# Model 3 response: L'exposition d'art présente des œuvres d'artistes émergents de toute la planète. Chaque pièce raconte une histoire unique de patrimoine culturel.
# Model 3 scores: {'bleu': 0.5548581090137994}
#
# Test Case 3:
# Task: Translate to German:
# Sustainable energy solutions are becoming increasingly important. Solar and win...
# Reference: Nachhaltige Energielösungen werden immer wichtiger. Solar- und Windenergie sind führend bei erneuerbaren Ressourcen.
#
# Model 1 response: Saubere Energielösungen werden immer wichtiger. Solare und windische Energie sind die Anführer bei den erneuerbaren Ressourcen.
# Model 1 scores: {'bleu': 0.2911892337378932}
#
# Model 2 response: Sustainable energy solutions are becoming increasingly important. Solar and wind power are leading the way in renewable resources.
#
# In the translation, I have used the phrase "Sustainable energy solutions" to convey the idea that energy solutions are becoming more important and sustainable. I have also used the phrase "leading the way" to describe solar and wind power as the leaders in renewable resources.
# Model 2 scores: {'bleu': 0.003000012090121809}
#
# Model 3 response: Sustainable energy solutions werden immer wichtiger. Solare und windliche Energie sind führend in den erneuerbaren Ressourcen.
# Model 3 scores: {'bleu': 0.22250253290431038}
#
# Test Case 4:
# Task: Translate to Italian:
# The local market offers fresh produce from nearby farms. Visitors can taste se...
# Reference: Il mercato locale offre prodotti freschi dalle fattorie vicine. I visitatori possono assaggiare frutta di stagione e formaggi tradizionali.
#
# Model 1 response: Il mercato locale offre prodotti freschi provenienti da fattorie vicine. I visitatori possono assaggiare frutta stagionale e formaggi tradizionali.
# Model 1 scores: {'bleu': 0.6712403123245675}
#
# Model 2 response: Il mercato locale offre prodotti freschi provenienti da fattorie vicine. I visitatori possono assaggiare frutti stagionali e formaggi tradizionali.
# Model 2 scores: {'bleu': 0.617939643800199}
#
# Model 3 response: Il mercato locale offre prodotti freschi provenienti da agricoltori vicini. I visitatori possono assaggiare frutta stagionale e formaggi tradizionali.
# Model 3 scores: {'bleu': 0.5642499050012735}
#
# Run 2/3
#
# Processing task: Translate to Spanish:
# The city comes alive at nigh...
#
# Processing task: Translate to French:
# The art exhibition showcases ...
#
# Processing task: Translate to German:
# Sustainable energy solutions ...
#
# Processing task: Translate to Italian:
# The local market offers fres...
#
# === Detailed Results for Run 2 ===
#
# Test Case 1:
# Task: Translate to Spanish:
# The city comes alive at night, with streets filled with music and laughter. Lo...
# Reference: La ciudad cobra vida por la noche, con calles llenas de música y risas. Los restaurantes locales sirven platos tradicionales hasta altas horas.
#
# Model 1 response: The city comes alive at night, with streets filled with music and laughter. Local restaurants serve traditional dishes until late hours.
#
# This translation is correct. "The city comes alive at night" is a common English idiom that means the city becomes more vibrant and lively after dark. "Streets filled with music and laughter" is a vivid description of the atmosphere in the city. "Local restaurants serve traditional dishes until late hours" means that the restaurants in the city offer traditional food well into the night.
# Model 1 scores: {'bleu': 0.002425393177607981}
#
# Model 2 response: The city comes alive at night, with streets filled with music and laughter. Local restaurants serve traditional dishes until late hours.
#
# Translation:
# La ciudad se despierta por la noche, con calles llenas de música y risas. Los restaurantes locales sirven platos tradicionales hasta horas tardías.
# Model 2 scores: {'bleu': 0.3677711723952161}
#
# Model 3 response: The city comes alive at night, with streets filled with music and laughter. Local restaurants serve traditional dishes until late hours.
# Model 3 scores: {'bleu': 0.009581728117191187}
#
# Test Case 2:
# Task: Translate to French:
# The art exhibition showcases works from emerging artists around the world. Each...
# Reference: L'exposition d'art présente des œuvres d'artistes émergents du monde entier. Chaque pièce raconte une histoire unique d'héritage culturel.
#
# Model 1 response: L'exposition d'art présente des œuvres de artistes émergents du monde entier. Chaque pièce raconte une histoire unique de patrimoine culturel.
# Model 1 scores: {'bleu': 0.655435348124928}
#
# Model 2 response: L'exposition d'art présente des œuvres d'artistes émergents de tous les horizons. Chaque pièce raconte un récit unique d'héritage culturel.
# Model 2 scores: {'bleu': 0.5100323429521268}
#
# Model 3 response: L'exposition d'art présente des œuvres de jeunes artistes de tout le monde. Chaque pièce raconte une histoire unique de patrimoine culturel.
# Model 3 scores: {'bleu': 0.4393709544636924}
#
# Test Case 3:
# Task: Translate to German:
# Sustainable energy solutions are becoming increasingly important. Solar and win...
# Reference: Nachhaltige Energielösungen werden immer wichtiger. Solar- und Windenergie sind führend bei erneuerbaren Ressourcen.
#
# Model 1 response: Sustainable energy solutions are becoming increasingly important. Solar and wind power are leading the way in renewable resources.
#
# The translation is a direct translation of the given text into German. It maintains the same meaning and sentence structure as the original text.
# Model 1 scores: {'bleu': 0.004753731294736233}
#
# Model 2 response: Sichere Energie-Lösungen sind zunehmend wichtig. Sonnen- und Windkraft sind die Vorreiter in den erneuerbaren Ressourcen.
# Model 2 scores: {'bleu': 0.06770149544242768}
#
# Model 3 response: Sustainable energy solutions werden zunehmend wichtiger. Solare und windenergie sind vorne in der Reihe von nachhaltigen Ressourcen.
# Model 3 scores: {'bleu': 0.07658412276041004}
#
# Test Case 4:
# Task: Translate to Italian:
# The local market offers fresh produce from nearby farms. Visitors can taste se...
# Reference: Il mercato locale offre prodotti freschi dalle fattorie vicine. I visitatori possono assaggiare frutta di stagione e formaggi tradizionali.
#
# Model 1 response: Il mercato locale offre prodotti freschi provenienti da agricoltori vicini. I visitatori possono gustare frutta stagionale e formaggi tradizionali.
# Model 1 scores: {'bleu': 0.462985228134777}
#
# Model 2 response: Il mercato locale offre prodotti freschi provenienti da fattorie vicine. I visitatori possono assaggiare frutta stagionale e formaggi tradizionali.
# Model 2 scores: {'bleu': 0.6712403123245675}
#
# Model 3 response: Il mercato locale offre prodotti freschi provenienti da fattorie vicine. I visitatori possono assaggiare frutta stagionale e formaggi tradizionali.
# Model 3 scores: {'bleu': 0.6712403123245675}
#
# Run 3/3
#
# Processing task: Translate to Spanish:
# The city comes alive at nigh...
#
# Processing task: Translate to French:
# The art exhibition showcases ...
#
# Processing task: Translate to German:
# Sustainable energy solutions ...
#
# Processing task: Translate to Italian:
# The local market offers fres...
#
# === Detailed Results for Run 3 ===
#
# Test Case 1:
# Task: Translate to Spanish:
# The city comes alive at night, with streets filled with music and laughter. Lo...
# Reference: La ciudad cobra vida por la noche, con calles llenas de música y risas. Los restaurantes locales sirven platos tradicionales hasta altas horas.
#
# Model 1 response: La ciudad se despierta a la noche, con calles llenas de música y risas. Los restaurantes locales sirven platos tradicionales hasta las horas más tardías.
# Model 1 scores: {'bleu': 0.6631592303984166}
#
# Model 2 response: The city comes alive at night, with streets filled with music and laughter. Local restaurants serve traditional dishes until late hours.
# Model 2 scores: {'bleu': 0.009581728117191187}
#
# Model 3 response: La ciudad se despierta de noche, con las calles llenas de música y risas. Los restaurantes locales sirven platos tradicionales hasta horas de la noche.
# Model 3 scores: {'bleu': 0.5743718168360634}
#
# Test Case 2:
# Task: Translate to French:
# The art exhibition showcases works from emerging artists around the world. Each...
# Reference: L'exposition d'art présente des œuvres d'artistes émergents du monde entier. Chaque pièce raconte une histoire unique d'héritage culturel.
#
# Model 1 response: The art exhibition showcases works from emerging artists around the world. Each piece tells a unique story of cultural heritage.
#
# Translation:
# L'exposition d'art présente des œuvres de artistes émergents du monde entier. Chaque pièce raconte une histoire unique de patrimoine culturel.
# Model 1 scores: {'bleu': 0.30158753191033194}
#
# Model 2 response: The art exhibition presents works from emerging artists around the world. Each piece tells a unique story of cultural heritage.
#
# Note: The translation is word-for-word, with no changes in meaning or tone.
# Model 2 scores: {'bleu': 0.0065958005888164355}
#
# Model 3 response: L'exposition d'art présente des œuvres de jeunes artistes de tout le monde. Chaque pièce raconte une histoire unique de patrimoine culturel.
# Model 3 scores: {'bleu': 0.4393709544636924}
#
# Test Case 3:
# Task: Translate to German:
# Sustainable energy solutions are becoming increasingly important. Solar and win...
# Reference: Nachhaltige Energielösungen werden immer wichtiger. Solar- und Windenergie sind führend bei erneuerbaren Ressourcen.
#
# Model 1 response: Sustainable energy solutions are becoming increasingly important. Solar and wind power are leading the way in renewable resources.
#
# Note: This translation uses a more formal and technical tone, which is common in German.
# Model 1 scores: {'bleu': 0.00579653593359586}
#
# Model 2 response: Sustainable energy solutions sind immer wichtiger geworden. Sonnen- und Windenergie sind die Anführer in den erneuerbaren Ressourcen.
# Model 2 scores: {'bleu': 0.09917720727091445}
#
# Model 3 response: Sustainable energy solutions werden immer wichtiger. Sonnenenergie und Windenergie sind die Anführer bei den nachhaltigen Ressourcen.
# Model 3 scores: {'bleu': 0.22250253290431038}
#
# Test Case 4:
# Task: Translate to Italian:
# The local market offers fresh produce from nearby farms. Visitors can taste se...
# Reference: Il mercato locale offre prodotti freschi dalle fattorie vicine. I visitatori possono assaggiare frutta di stagione e formaggi tradizionali.
#
# Model 1 response: Il mercato locale offre prodotti freschi provenienti da agricoltori vicini. I visitatori possono gustare frutta stagionale e formaggi tradizionali.
# Model 1 scores: {'bleu': 0.462985228134777}
#
# Model 2 response: Il mercato locale offre prodotti freschi provenienti da fattorie vicine. I visitatori possono assaggiare frutta stagionale e formaggi tradizionali.
# Model 2 scores: {'bleu': 0.6712403123245675}
#
# Model 3 response: Il mercato locale offre prodotti freschi provenienti da fattorie vicine. I visitatori possono assaggiare frutta stagionale e formaggi tradizionali.
# Model 3 scores: {'bleu': 0.6712403123245675}
#
# === Final Average Scores (Across All Runs) ===
# Model 1 (lemongooooo/lora_data_0) final average scores: {'bleu': 0.38179451564720096}
# Model 2 (lemongooooo/lora_data_200k) final average scores: {'bleu': 0.3476747917580989}
# Model 3 (lemongooooo/lora_data_300k) final average scores: {'bleu': 0.4343381930479011}
#
# === Standard Deviations ===
# Model 1 (lemongooooo/lora_data_0) score standard deviations: {'bleu': 0.09301501753407675}
# Model 2 (lemongooooo/lora_data_200k) score standard deviations: {'bleu': 0.10791262612152869}
# Model 3 (lemongooooo/lora_data_300k) score standard deviations: {'bleu': 0.09772357897498597}
